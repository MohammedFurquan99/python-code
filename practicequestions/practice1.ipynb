# %%
# Variables in Python

name = "Ali"          
age = 22             
height = 5.9         



print("Name:", name)
print("Age:", age)
print("Height:", height)
# Out:
# Name: Ali
# Age: 22
# Height: 5.9
