# %%
# Variables in Python

name = "Ali"          
age = 22             
height = 5.9         



print("Name:", name)
print("Age:", age)
print("Height:", height)
# Out:
# Name: Ali
# Age: 22
# Height: 5.9

# %%
#append mode
list = ["furquan", "shaoib", "sarmas", "hatif", "vinod"]
list.append("aneek")
print(list)
# Out:
# ['furquan', 'shaoib', 'sarmas', 'hatif', 'vinod', 'aneek']

# %%
#sorts in ascending order 
list = [1,2,4,5,7,2,5,97,4,7,6,9,]
print(list.sort())
print(list)
# Out:
# None
# [1, 2, 2, 4, 4, 5, 5, 6, 7, 7, 9, 97]

# %%
# sorts in decending order
nums = [1,2,4,5,7,2,5,97,4,7,6,9,100000]
print(nums.sort(reverse=True))
print(nums)
# Out:
# None
# [100000, 97, 9, 7, 7, 6, 5, 5, 4, 4, 2, 2, 1]

# %%
#revers the list
list = [3,232,23,4,55657,554,476568645,334,5,]
print(list.reverse())
print(list)
# Out:
# None
# [5, 334, 476568645, 554, 55657, 4, 23, 232, 3]

# %%
2100%400
# Out:
# 100

# %%
#finding index
name  = "mohammed furquan ashrafii"
ch = name[7]
print(ch)
# Out:
# d

# %%
#slicing
name = "mohammed furquan ashrfi"
print(name[0:14])
# Out:
# mohammed furqu
